# %% [markdown]
# # User Trasaction Matrix

# %%
# dataset : => https://www.kaggle.com/datasets/vivek468/superstore-dataset-final

# %% [markdown]
# # 3. User Trasaction Matrix

# %%
import pandas as pd
 

superstore = pd.read_csv('Sample_Superstore.csv', encoding='windows-1252', index_col="Row ID") 
        #วิธีเเก้มาจาก stackoverflow ('utf-8' codec can't decode byte 0xa0 in position 4276: invalid start byte)
        # index_col => optional
superstore.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country</th>
#       <th>City</th>
#       <th>State</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Row ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
superstore['Order Date'] = pd.to_datetime(superstore["Order Date"])
superstore['Ship Date'] = pd.to_datetime(superstore['Ship Date' ])
superstore['Postal Code'] = superstore['Postal Code'].astype(str)

# %% [markdown]
# ### 3.1 View potential input columns

# %%
superstore[['Order Date', 'Customer ID', 'Category', 'Sub-Category']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Order Date</th>
#       <th>Customer ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#     </tr>
#     <tr>
#       <th>Row ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>11/8/2016</td>
#       <td>CG-12520</td>
#       <td>Furniture</td>
#       <td>Bookcases</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>11/8/2016</td>
#       <td>CG-12520</td>
#       <td>Furniture</td>
#       <td>Chairs</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6/12/2016</td>
# ...

# %% [markdown]
# ### 3.2User Pivot Table to convert

# %%
superstore.pivot_table(index='Customer ID',
                       columns=['Category', 'Sub-Category'],
                       values='Order ID',
                       aggfunc='count',
                       fill_value=0)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
#
#     .dataframe thead tr:last-of-type th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th>Category</th>
#       <th colspan="4" halign="left">Furniture</th>
#       <th colspan="9" halign="left">Office Supplies</th>
#       <th colspan="4" halign="left">Technology</th>
#     </tr>
#     <tr>
#       <th>Sub-Category</th>
#       <th>Bookcases</th>
#       <th>Chairs</th>
#       <th>Furnishings</th>
#       <th>Tables</th>
#       <th>Appliances</th>
#       <th>Art</th>
#       <th>Binders</th>
#       <th>Envelopes</th>
#       <th>Fasteners</th>
#       <th>Labels</th>
#       <th>Paper</th>
#       <th>Storage</th>
#       <th>Supplies</th>
# ...

# %% [markdown]
# ตารางด้านบนจะมีไว้เปรียบเทียบลูกค้า เช่น มีพฤติกรรมเหมือนกันมั่ย หรือว่าควรจัดโปรเเบบไหน เพื่อดึงดูดลูกค้ากลุ่มนั้นๆ
